# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_predictions_vs_ground_truth(json_file_path):
    # Read the JSON file
    with open(json_file_path, 'r') as file:
        data = json.load(file)
    
    # Extract predictions and ground truth
    predictions = np.array(data['Prediction'])
    ground_truth = np.array(data['Ground-Truth'])
    
    # Create the plot
    plt.figure(figsize=(6, 6))
    
    # Plot the scatter points
    plt.scatter(ground_truth, predictions, color='blue', alpha=0.2, label='Data Points')
    
    # Calculate the range for the x=y line
    min_val = min(ground_truth.min(), predictions.min())
    max_val = max(ground_truth.max(), predictions.max())
    
    # Plot x=y line
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='x=y Line')
    
    # Customize the plot
    plt.xlabel('Ground Truth')
    plt.ylabel('Predictions')
    plt.title('Predictions vs Ground Truth')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    
    # Set aspect ratio to equal for a square plot
    plt.axis('equal')
    
    # Adjust plot limits to include all points
    plt.xlim(min_val, max_val)
    plt.ylim(min_val, max_val)
    
    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
# for model in ['GNN', 'GNNAK', 'IDGNN', 'PPGN', 'I2GNN', 'ESC-GNN']:
#     json_file_path = f'/userhome/matin/Dev/MLSC/output/data_esc/{model}/target_2.json'
#     plot_predictions_vs_ground_truth(json_file_path)
# output/pretrain/GNN/target_7.json
json_file_path = '/userhome/matin/Dev/MLSC/output/data_esc/GNN/target_8.json'
plot_predictions_vs_ground_truth(json_file_path)
